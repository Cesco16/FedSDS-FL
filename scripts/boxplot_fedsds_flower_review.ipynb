# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
i = [99,199,299,399,499,599,699,799,899,999]
fold = 'MDS'
exp = 'mds'

c11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
c22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
c33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

C1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
C2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
C3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

FP1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FP2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FP3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

FN1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FN2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FN3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

C11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_biased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)
C22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_biased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)
C33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_biased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)

G11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_unbiased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)
G22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_unbiased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)
G33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_unbiased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)

CC1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
CC2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
CC3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

# %%
FP1a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_ok_0.1.csv', header=None)[1][:1000]
FP1b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_ok_0.3.csv', header=None)[1][:1000]
FP1c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_ok_0.6.csv', header=None)[1][:1000]
FP1d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_ok_0.9.csv', header=None)[1][:1000]
FP1e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_ok_1.0.csv', header=None)[1][:1000]

FP2a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_ok_0.1.csv', header=None)[1][:1000]
FP2b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_ok_0.3.csv', header=None)[1][:1000]
FP2c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_ok_0.6.csv', header=None)[1][:1000]
FP2d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_ok_0.9.csv', header=None)[1][:1000]
FP2e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_ok_1.0.csv', header=None)[1][:1000]

FP3a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_ok_0.1.csv', header=None)[1][:1000]
FP3b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_ok_0.3.csv', header=None)[1][:1000]
FP3c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_ok_0.6.csv', header=None)[1][:1000]
FP3d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_ok_0.9.csv', header=None)[1][:1000]
FP3e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_ok_1.0.csv', header=None)[1][:1000]

# %%
print(np.mean(FP3a))
print(np.mean(FP3b))
print(np.mean(FP3c))
print(np.mean(FP3d))
print(np.mean(FP3e))
# Out:
# 0.655271552335309
# 0.6524883021864268
# 0.648757514959023
# 0.6588264676083343
# 0.6578738781628495

# %%
box11 = pd.DataFrame({'C-index':c11, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 1']*10})
box22 = pd.DataFrame({'C-index':c22, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 2']*10})
box33 = pd.DataFrame({'C-index':c33, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 3']*10})

boxf1 = pd.DataFrame({'C-index':C1, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 1']*10})
boxf2 = pd.DataFrame({'C-index':C2, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 2']*10})
boxf3 = pd.DataFrame({'C-index':C3, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 3']*10})

boxfp1 = pd.DataFrame({'C-index':FP1, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 1']*10})
boxfp2 = pd.DataFrame({'C-index':FP2, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 2']*10})
boxfp3 = pd.DataFrame({'C-index':FP3, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 3']*10})

boxfn1 = pd.DataFrame({'C-index':FN1, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 1']*10})
boxfn2 = pd.DataFrame({'C-index':FN2, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 2']*10})
boxfn3 = pd.DataFrame({'C-index':FN3, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 3']*10})

boxu1 = pd.DataFrame({'C-index':G11, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 1']*10})
boxu2 = pd.DataFrame({'C-index':G22, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 2']*10})
boxu3 = pd.DataFrame({'C-index':G33, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 3']*10})

boxb1 = pd.DataFrame({'C-index':C11, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 1']*10})
boxb2 = pd.DataFrame({'C-index':C22, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 2']*10})
boxb3 = pd.DataFrame({'C-index':C33, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 3']*10})

boxc1 = pd.DataFrame({'C-index':CC1, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 1']*10})
boxc2 = pd.DataFrame({'C-index':CC2, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 2']*10})
boxc3 = pd.DataFrame({'C-index':CC3, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 3']*10})

# %%
BOX = pd.concat((box11, box22), axis=0)
BOX = pd.concat((BOX, box33), axis=0)
BOX = pd.concat((BOX, boxf1), axis=0)
BOX = pd.concat((BOX, boxf2), axis=0)
BOX = pd.concat((BOX, boxf3), axis=0)
BOX = pd.concat((BOX, boxfp1), axis=0)
BOX = pd.concat((BOX, boxfp2), axis=0)
BOX = pd.concat((BOX, boxfp3), axis=0)
BOX = pd.concat((BOX, boxfn1), axis=0)
BOX = pd.concat((BOX, boxfn2), axis=0)
BOX = pd.concat((BOX, boxfn3), axis=0)
BOX = pd.concat((BOX, boxu1), axis=0)
BOX = pd.concat((BOX, boxu2), axis=0)
BOX = pd.concat((BOX, boxu3), axis=0)
BOX = pd.concat((BOX, boxb1), axis=0)
BOX = pd.concat((BOX, boxb2), axis=0)
BOX = pd.concat((BOX, boxb3), axis=0)
BOX = pd.concat((BOX, boxc1), axis=0)
BOX = pd.concat((BOX, boxc2), axis=0)
BOX = pd.concat((BOX, boxc3), axis=0)

# %%
import numpy as np
from scipy import stats

for dd in [c11, c22,c33, C1, C2, C3,FP1,FP2,FP3,FN1,FN2,FN3,G11, G22,G33, C11, C22,C33]:
    print('mean: ', np.mean(dd), ' confidence interval: ', stats.t.interval(0.95, len(dd)-1, loc=np.mean(dd), scale=stats.sem(dd)))
# Out:
# mean:  0.6717020645363956  confidence interval:  (0.6700287599959416, 0.6733753690768496)
# mean:  0.7095473769459192  confidence interval:  (0.7079399199829554, 0.711154833908883)
# mean:  0.6885361426991465  confidence interval:  (0.6872840009461856, 0.6897882844521075)
# mean:  0.685068323414949  confidence interval:  (0.6840436817789249, 0.6860929650509732)
# mean:  0.7238939380305348  confidence interval:  (0.7226295504686183, 0.7251583255924513)
# mean:  0.6840370927034002  confidence interval:  (0.6829671054335619, 0.6851070799732385)
# mean:  0.6763651594213015  confidence interval:  (0.6752310702604649, 0.6774992485821381)
# mean:  0.7092714238579442  confidence interval:  (0.7075295005867516, 0.7110133471291368)
# mean:  0.6774253466806567  confidence interval:  (0.6762338957225776, 0.6786167976387357)
# mean:  0.6818554650006108  confidence interval:  (0.680372605038826, 0.6833383249623955)
# ...

# %%
# FACCIO IL TEST SOLO TRA I CORRISPONDENTI
from scipy.stats import mannwhitneyu, wilcoxon
from statsmodels.stats.multitest import multipletests

p_values = []
labels = []

alternative = 'greater'

def corrected_test(group1, group2, label):
    #stat, p = mannwhitneyu(round(group1,3), round(group2,3), alternative=alternative
    try:
        stat, p = wilcoxon(round(group1,3), round(group2,3), alternative=alternative)
        #stat, p = wilcoxon(group1, group2, alternative=alternative)
    except:
        p = 1.0
        label = "identity"
    p_values.append(p)
    labels.append(label)
    #print(f"{label}: statistic={stat}, raw p-value={p}")

#n1 = [c11,c21,c31,C1,G11,G21,G31,C11,C21,C31]
n1 = [c11, C1, G11, C11]
#n2 = [c12,c22,c32,C2,G12,G22,G32,C12,C22,C32]
n2 = [c22, C2, G22, C22]
#n3 = [c13,c23,c33,C3,G13,G23,G33,C13,C23,C33]
n3 = [c33, C3, G33, C33]

medie1 = [np.mean(array) for array in n1]
medie2 = [np.mean(array) for array in n2]
medie3 = [np.mean(array) for array in n3]

indice1= np.argmax(medie1)
indice2= np.argmax(medie2)
indice3= np.argmax(medie3)


# Seleziona l'array con la media più alta
max1 = n1[indice1]
max2 = n2[indice2]
max3 = n3[indice3]



# Run your tests (abbreviated for clarity; use all 30 like before)
corrected_test(max1, c11, "f11 vs i11")
#corrected_test(max1, c21, "f11 vs i21")
#corrected_test(max1, c31, "f11 vs i11")

#corrected_test(max2, c12, "f22 vs i12")
corrected_test(max2, c22, "f22 vs i22")
#corrected_test(max2, c32, "f2 vs i32")
corrected_test(max3, c33, "f33 vs i33")
#corrected_test(max3, c13, "f33 vs i13")
#corrected_test(max3, c23, "f33 vs i23")


corrected_test(max1, C1, "f11 vs avg11")
corrected_test(max2, C2, "f22 vs avg22")
corrected_test(max3, C3, "f33 vs avg33")

corrected_test(max1, FP1, "f11 vs fprox11")
corrected_test(max2, FP2, "f22 vs fprox22")
corrected_test(max3, FP3, "f33 vs fprox33")

corrected_test(max1, FN1, "f11 vs fnova11")
corrected_test(max2, FN2, "f22 vs fnova22")
corrected_test(max3, FN3, "f33 vs fnova33")


corrected_test(max1, G11, "f11 vs g11")
#corrected_test(max1, G21, "f11 vs g21")
#corrected_test(max1, G31, "f11 vs g11")

#corrected_test(max2, G12, "f11 vs g11")
corrected_test(max2, G22, "f22 vs g22")
#corrected_test(max2, G32, "f11 vs g11")
corrected_test(max3, G33, "f33 vs g33")
#corrected_test(max3, G13, "f11 vs g11")
#corrected_test(max3, G23, "f11 vs g21")


corrected_test(max1, C11, "f11 vs f11")
#corrected_test(max1, C21, "f11 vs f21")
#corrected_test(max1, C31, "f11 vs f31")

#corrected_test(max2, C12, "f11 vs f12")
corrected_test(max2, C22, "f22 vs f22")
#corrected_test(max2, C32, "f11 vs f32")
corrected_test(max3, C33, "f33 vs f33")
#corrected_test(max3, C13, "f11 vs f13")
#corrected_test(max3, C23, "f11 vs f23")


# Apply Holm-Bonferroni correction (FWER control)
reject, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='holm')

print(f"\nHolm-Bonferroni correction applied (FWER control).")
for i in range(len(p_values)):
    print(f"{labels[i]}: corrected p-value = {pvals_corrected[i]}, significant: {reject[i]}")
# Out:
# Holm-Bonferroni correction applied (FWER control).
# f11 vs i11: corrected p-value = 0.017578125, significant: True
# f22 vs i22: corrected p-value = 0.017578125, significant: True
# f33 vs i33: corrected p-value = 0.017578125, significant: True
# f11 vs avg11: corrected p-value = 0.017578125, significant: True
# f22 vs avg22: corrected p-value = 0.017578125, significant: True
# f33 vs avg33: corrected p-value = 0.017578125, significant: True
# f11 vs fprox11: corrected p-value = 0.017578125, significant: True
# f22 vs fprox22: corrected p-value = 0.017578125, significant: True
# f33 vs fprox33: corrected p-value = 0.017578125, significant: True
# f11 vs fnova11: corrected p-value = 0.017578125, significant: True
# f22 vs fnova22: corrected p-value = 0.017578125, significant: True
# f33 vs fnova33: corrected p-value = 0.017578125, significant: True
# f11 vs g11: corrected p-value = 0.017578125, significant: True
# identity: corrected p-value = 1.0, significant: False
# ...

# %%
#sns.boxplot(data = BOX, x = 'node_type', y = 'C-index', hue='mode')
#plt.title('Isolated vs FedAvg vs FedSDS')
#plt.legend(title='Models',loc='upper left', bbox_to_anchor=(1, 1))
#plt.xlabel('Client where the model is evaluated')
#plt.ylim(0.65,0.76)
#plt.grid()
colors = ['#0C7BDC','#E66100','#FFC20A','#2C7300','#8C564B']
colors = ['#0C7BDC', '#E66100', '#FFC20A', '#2C7300', '#8C564B', '#029E73', '#CC78BC']
# Crea la figura con 3 sottoplot
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=False)
#colors = sns.color_palette("husl", n_colors=len(BOX['mode'].unique()))
# Disegna 4 boxplot per ogni sottoplot
clienti = ['Client 1', 'Client 2','Client 3']
i = 0
for i, ax in enumerate(axes):
    
    
    sns.boxplot(
        data=BOX[BOX['node_type']==clienti[i]],
        x='node_type',
        y='C-index',
        hue='mode',
        ax=ax,
        palette=colors,
        dodge=True  # Separa i boxplot per 'mode'
    )
    
    if i == 0:
        x1, x2 = -0.35, 0.23  # positions for groups A and B
        y, h, col = 0.759, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)

        x1, x2 = -0.22, 0.23  # positions for groups A and B
        y, h, col = 0.753, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)

        x1, x2 = -0.09, 0.23# positions for groups A and B
        y, h, col = 0.747, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        x1, x2 = 0.0, 0.23# positions for groups A and B
        y, h, col = 0.741, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        x1, x2 = 0.13, 0.23# positions for groups A and B
        y, h, col = 0.735, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        ax.set_ylim(0.665, 0.765)
        
    elif i == 1:
        x1, x2 = -0.4, 0.13#-0.15  # positions for groups A and B
        y, h, col = 0.762, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        x1, x2 = -0.27, 0.13#-0.15  # positions for groups A and B
        y, h, col = 0.758, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        x1, x2 = -0.14, 0.13#-0.15  # positions for groups A and B
        y, h, col = 0.754, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)

        x1, x2 = 0.0, 0.13  # positions for groups A and B
        y, h, col = 0.75, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        ax.set_ylim(0.703, 0.766)
        
#x1, x2 = 1.0, 1.15  # positions for groups A and B
#y, h, col = 0.76, 0.005, 'k'  # y position, height, and color
#plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
#plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)
    elif i == 2:
        x1, x2 = -0.35, 0.23  # positions for groups A and B
        y, h, col = 0.722, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)

        x1, x2 = -0.22, 0.23  # positions for groups A and B
        y, h, col = 0.719, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)

        x1, x2 = -0.09, 0.23  # positions for groups A and B
        y, h, col = 0.716, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        x1, x2 = 0.0, 0.23  # positions for groups A and B
        y, h, col = 0.713, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        x1, x2 = 0.13, 0.23  # positions for groups A and B
        y, h, col = 0.71, 0.001, 'k'  # y position, height, and color
        ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
        ax.text((x1+x2)*.5, y+0.000001, "*", ha='center', va='bottom', color=col, fontsize=15)
        
        ax.set_ylim(0.670, 0.726)
    
    #y_min = BOX[BOX['node_type']==clienti[i]]['C-index'].min()
    #y_max = BOX[BOX['node_type']==clienti[i]]['C-index'].max()
    #y_range = y_max - y_min

    # Aggiungi un margine (es. 10%) per migliorare la visualizzazione
    #y_margin = 0.3 * y_range
    #ax.set_ylim(y_min - 0.01, y_max + 0.02)
    
    ax.set_title(f'Client {i+1}', fontsize=14, pad=10)
    ax.set_ylabel('C-index', fontsize=12)
    ax.set_xlabel('', fontsize=12)
    ax.grid(True, linestyle='--', alpha=0.85)
    ax.get_legend().remove()# Rimuove la legenda locale (la metteremo fuori)
    
    
    
    
    i += 1

# Legenda unica (basata su 'mode')
handles, labels = axes[0].get_legend_handles_labels()  # Prende le handles e labels dal primo sottoplot
fig.legend(
    handles=handles,
    labels=labels,
    loc='center left',  # Posizione verticale a destra
    bbox_to_anchor=(1, 0.5),
    #ncol=len(labels),  # Una colonna per ogni 'mode'
    fontsize=12
)

# Titolo comune per l'asse x
fig.text(0.525, 0.02, 'Clients', ha='center', fontsize=12)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])  # Regola lo spazio per la legenda
plt.savefig('C:/Users/Lenovo/Desktop/FedSDS_review/boxplot_mds_ok_reviewed.png', bbox_inches='tight')
plt.show()

# %%
i = [99,199,299,399,499,599,699,799,899,999]
fold = 'LGG'
exp = 'lgg'

c11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
c22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

C1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
C2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)


FP1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.6_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FP2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.6_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#FP3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

FN1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FN2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#FN3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

C11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_biased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
C22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_biased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#C33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_biased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)

G11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
G22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#G33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_unbiased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)

CC1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
CC2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#CC3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

# %%
FP1a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.1_ok.csv', header=None)[1][:1000]
FP1b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.3_ok.csv', header=None)[1][:1000]
FP1c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.6_ok.csv', header=None)[1][:1000]
FP1d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000]
#FP1e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_1.0_ok.csv', header=None)[1][:1000]

FP2a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.1_ok.csv', header=None)[1][:1000]
FP2b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.3_ok.csv', header=None)[1][:1000]
FP2c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.6_ok.csv', header=None)[1][:1000]
FP2d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000]
#FP2e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_1.0_ok.csv', header=None)[1][:1000]

# %%
print(np.mean(FP2a))
print(np.mean(FP2b))
print(np.mean(FP2c))
print(np.mean(FP2d))
#print(np.mean(FP2e))
# Out:
# 0.6552682926829275
# 0.6547100271002712
# 0.6539769647696475
# 0.6530840108401084

# %%
#BOXPLOT LGG
box11 = pd.DataFrame({'C-index':c11, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 1']*10})
box22 = pd.DataFrame({'C-index':c22, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 2']*10})


boxf1 = pd.DataFrame({'C-index':C1, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 1']*10})
boxf2 = pd.DataFrame({'C-index':C2, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 2']*10})


boxfp1 = pd.DataFrame({'C-index':FP1, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 1']*10})
boxfp2 = pd.DataFrame({'C-index':FP2, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 2']*10})


boxfn1 = pd.DataFrame({'C-index':FN1, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 1']*10})
boxfn2 = pd.DataFrame({'C-index':FN2, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 2']*10})


boxu1 = pd.DataFrame({'C-index':G11, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 1']*10})
boxu2 = pd.DataFrame({'C-index':G22, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 2']*10})


boxb1 = pd.DataFrame({'C-index':C11, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 1']*10})
boxb2 = pd.DataFrame({'C-index':C22, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 2']*10})


boxc1 = pd.DataFrame({'C-index':CC1, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 1']*10})
boxc2 = pd.DataFrame({'C-index':CC2, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 2']*10})




BOX = pd.concat((box11, box22), axis=0)

BOX = pd.concat((BOX, boxf1), axis=0)
BOX = pd.concat((BOX, boxf2), axis=0)

BOX = pd.concat((BOX, boxfp1), axis=0)
BOX = pd.concat((BOX, boxfp2), axis=0)

BOX = pd.concat((BOX, boxfn1), axis=0)
BOX = pd.concat((BOX, boxfn2), axis=0)

BOX = pd.concat((BOX, boxu1), axis=0)
BOX = pd.concat((BOX, boxu2), axis=0)

BOX = pd.concat((BOX, boxb1), axis=0)
BOX = pd.concat((BOX, boxb2), axis=0)

BOX = pd.concat((BOX, boxc1), axis=0)
BOX = pd.concat((BOX, boxc2), axis=0)

colors = ['#0C7BDC', '#E66100', '#FFC20A', '#2C7300', '#8C564B', '#029E73', '#CC78BC']
sns.boxplot(data = BOX, x = 'node_type', y = 'C-index', hue='mode', palette=colors)

x1, x2 = -0.39, 0.25  # positions for groups A and B
y, h, col = 0.98, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = -0.26, 0.25  # positions for groups A and B
y, h, col = 0.94, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = -0.13, 0.25  # positions for groups A and B
y, h, col = 0.90, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.00, 0.25  # positions for groups A and B
y, h, col = 0.86, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.13, 0.25  # positions for groups A and B
y, h, col = 0.82, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

#x1, x2 = 0.7, 1.3  # positions for groups A and B
#y, h, col = 0.86, 0.005, 'k'  # y position, height, and color
#plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
#plt.text((x1+x2)*.5, y+h+0.001, "**", ha='center', va='bottom', color=col, fontsize=15)

#x1, x2 = 0.65, 1.23  # positions for groups A and B
#y, h, col = 0.98, 0.005, 'k'  # y position, height, and color
#plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
#plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.75, 1.23  # positions for groups A and B
y, h, col = 0.94, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.87, 1.23  # positions for groups A and B
y, h, col = 0.90, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 1.0, 1.23  # positions for groups A and B
y, h, col = 0.86, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 1.13, 1.23  # positions for groups A and B
y, h, col = 0.82, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

plt.title('Isolated vs FedAvg vs FedSDS - LGG')
plt.legend(title='Models',loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('Client where the model is evaluated')
plt.ylim(0.50,1.02)
plt.grid()
plt.savefig('C:/Users/Lenovo/Desktop/FedSDS_review/allboxplot_lgg_review.png', bbox_inches='tight')

# %%
import numpy as np
from scipy import stats

for dd in [c11, c22, C1, C2,FP1,FP2,FN1,FN2,G11, G22, C11, C22]:
    print('mean: ', np.mean(dd), ' confidence interval: ', stats.t.interval(0.95, len(dd)-1, loc=np.mean(dd), scale=stats.sem(dd)))
# Out:
# mean:  0.7102564102564103  confidence interval:  (0.700397620926812, 0.7201151995860086)
# mean:  0.7281842818428184  confidence interval:  (0.6894110113064411, 0.7669575523791956)
# mean:  0.6807692307692308  confidence interval:  (0.6661398933146642, 0.6953985682237974)
# mean:  0.6991869918699187  confidence interval:  (0.6847372477878603, 0.7136367359519772)
# mean:  0.6794871794871795  confidence interval:  (0.663899064860532, 0.6950752941138271)
# mean:  0.6991869918699187  confidence interval:  (0.6843945184786714, 0.7139794652611661)
# mean:  0.6807692307692308  confidence interval:  (0.6661398933146642, 0.6953985682237974)
# mean:  0.6991869918699187  confidence interval:  (0.6847372477878603, 0.7136367359519772)
# mean:  0.5833333333333333  confidence interval:  (0.5584035938940318, 0.6082630727726347)
# mean:  0.5989159891598916  confidence interval:  (0.5901981099527988, 0.6076338683669845)
# ...

# %%
# FACCIO IL TEST SOLO TRA I CORRISPONDENTI
from scipy.stats import mannwhitneyu, wilcoxon
from statsmodels.stats.multitest import multipletests

p_values = []
labels = []

alternative = 'greater'

def corrected_test(group1, group2, label):
    #stat, p = mannwhitneyu(round(group1,3), round(group2,3), alternative=alternative
    try:
        stat, p = wilcoxon(round(group1,3), round(group2,3), alternative=alternative)
        #stat, p = wilcoxon(group1, group2, alternative=alternative)
    except:
        p = 1.0
        label = "identity"
    p_values.append(p)
    labels.append(label)
    #print(f"{label}: statistic={stat}, raw p-value={p}")

#n1 = [c11,c21,c31,C1,G11,G21,G31,C11,C21,C31]
n1 = [c11, C1, G11, C11]
#n2 = [c12,c22,c32,C2,G12,G22,G32,C12,C22,C32]
n2 = [c22, C2, G22, C22]
#n3 = [c13,c23,c33,C3,G13,G23,G33,C13,C23,C33]
#n3 = [c33, C3, G33, C33]

medie1 = [np.mean(array) for array in n1]
medie2 = [np.mean(array) for array in n2]
#medie3 = [np.mean(array) for array in n3]

indice1= np.argmax(medie1)
indice2= np.argmax(medie2)
#indice3= np.argmax(medie3)


# Seleziona l'array con la media più alta
max1 = n1[indice1]
max2 = n2[indice2]
#max3 = n3[indice3]



# Run your tests (abbreviated for clarity; use all 30 like before)
corrected_test(max1, c11, "f11 vs i11")
#corrected_test(max1, c21, "f11 vs i21")
#corrected_test(max1, c31, "f11 vs i11")

#corrected_test(max2, c12, "f22 vs i12")
corrected_test(max2, c22, "f22 vs i22")
#corrected_test(max2, c32, "f2 vs i32")
#corrected_test(max3, c33, "f33 vs i33")
#corrected_test(max3, c13, "f33 vs i13")
#corrected_test(max3, c23, "f33 vs i23")


corrected_test(max1, C1, "f11 vs avg11")
corrected_test(max2, C2, "f22 vs avg22")
#corrected_test(max3, C3, "f33 vs avg33")

corrected_test(max1, FP1, "f11 vs fprox11")
corrected_test(max2, FP2, "f22 vs fprox22")
#corrected_test(max3, FP3, "f33 vs fprox33")

corrected_test(max1, FN1, "f11 vs fnova11")
corrected_test(max2, FN2, "f22 vs fnova22")
#corrected_test(max3, FN3, "f33 vs fnova33")


corrected_test(max1, G11, "f11 vs g11")
#corrected_test(max1, G21, "f11 vs g21")
#corrected_test(max1, G31, "f11 vs g11")

#corrected_test(max2, G12, "f11 vs g11")
corrected_test(max2, G22, "f22 vs g22")
#corrected_test(max2, G32, "f11 vs g11")
#corrected_test(max3, G33, "f33 vs g33")
#corrected_test(max3, G13, "f11 vs g11")
#corrected_test(max3, G23, "f11 vs g21")


corrected_test(max1, C11, "f11 vs f11")
#corrected_test(max1, C21, "f11 vs f21")
#corrected_test(max1, C31, "f11 vs f31")

#corrected_test(max2, C12, "f11 vs f12")
corrected_test(max2, C22, "f22 vs f22")
#corrected_test(max2, C32, "f11 vs f32")
#corrected_test(max3, C33, "f33 vs f33")
#corrected_test(max3, C13, "f11 vs f13")
#corrected_test(max3, C23, "f11 vs f23")


# Apply Holm-Bonferroni correction (FWER control)
reject, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='holm')

print(f"\nHolm-Bonferroni correction applied (FWER control).")
for i in range(len(p_values)):
    print(f"{labels[i]}: corrected p-value = {pvals_corrected[i]}, significant: {reject[i]}")
# Out:
# Holm-Bonferroni correction applied (FWER control).
# f11 vs i11: corrected p-value = 0.01473714925274986, significant: True
# f22 vs i22: corrected p-value = 0.158203125, significant: False
# f11 vs avg11: corrected p-value = 0.01171875, significant: True
# f22 vs avg22: corrected p-value = 0.013671875, significant: True
# f11 vs fprox11: corrected p-value = 0.01171875, significant: True
# f22 vs fprox22: corrected p-value = 0.013671875, significant: True
# f11 vs fnova11: corrected p-value = 0.01171875, significant: True
# f22 vs fnova22: corrected p-value = 0.013671875, significant: True
# f11 vs g11: corrected p-value = 0.01171875, significant: True
# f22 vs g22: corrected p-value = 0.01171875, significant: True
# identity: corrected p-value = 1.0, significant: False
# identity: corrected p-value = 1.0, significant: False
# ...

# %%
i = [99,199,299,399,499,599,699,799,899,999]
fold = 'BRCA'
exp = 'brca'

c11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
c22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

C1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
C2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedavg_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)


FP1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.3_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FP2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.3_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#FP3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

FN1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
FN2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#FN3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_fednova_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

C11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_biased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
C22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_biased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#C33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_biased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)

G11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
G22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#G33 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_unbiased_1700.csv', header=None)[1][:1000][i].reset_index(drop=True)

CC1 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
CC2 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
#CC3 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node3/'+fold+'/node3_'+exp+'_centralized_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)

# %%
FP1a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.1_ok.csv', header=None)[1][:1000]
FP1b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.3_ok.csv', header=None)[1][:1000]
FP1c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.6_ok.csv', header=None)[1][:1000]
FP1d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000]
#FP1e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_fedprox_1.0_ok.csv', header=None)[1][:1000]

FP2a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.1_ok.csv', header=None)[1][:1000]
FP2b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.3_ok.csv', header=None)[1][:1000]
FP2c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.6_ok.csv', header=None)[1][:1000]
FP2d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_0.9_ok.csv', header=None)[1][:1000]
#FP2e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_fedprox_1.0_ok.csv', header=None)[1][:1000]

# %%
print(np.mean(FP2a))
print(np.mean(FP2b))
print(np.mean(FP2c))
print(np.mean(FP2d))
print(np.mean(FP2e))
# Out:
# 0.6843457943925241
# 0.6882162883845128
# 0.690558077436582
# 0.6933150867823776
# 0.6579839227331351

# %%
#BOXPLOT BRCA
box11 = pd.DataFrame({'C-index':c11, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 1']*10})
box22 = pd.DataFrame({'C-index':c22, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 2']*10})


boxf1 = pd.DataFrame({'C-index':C1, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 1']*10})
boxf2 = pd.DataFrame({'C-index':C2, 
                   'mode': ['FedAvg']*10,
                  'node_type':['Client 2']*10})


boxfp1 = pd.DataFrame({'C-index':FP1, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 1']*10})
boxfp2 = pd.DataFrame({'C-index':FP2, 
                   'mode': ['FedProx']*10,
                  'node_type':['Client 2']*10})


boxfn1 = pd.DataFrame({'C-index':FN1, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 1']*10})
boxfn2 = pd.DataFrame({'C-index':FN2, 
                   'mode': ['FedNova']*10,
                  'node_type':['Client 2']*10})


boxu1 = pd.DataFrame({'C-index':G11, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 1']*10})
boxu2 = pd.DataFrame({'C-index':G22, 
                   'mode': ['FedSDS - unbiased']*10,
                  'node_type':['Client 2']*10})


boxb1 = pd.DataFrame({'C-index':C11, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 1']*10})
boxb2 = pd.DataFrame({'C-index':C22, 
                   'mode': ['FedSDS - biased']*10,
                  'node_type':['Client 2']*10})


boxc1 = pd.DataFrame({'C-index':CC1, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 1']*10})
boxc2 = pd.DataFrame({'C-index':CC2, 
                   'mode': ['Centralized']*10,
                  'node_type':['Client 2']*10})




BOX = pd.concat((box11, box22), axis=0)

BOX = pd.concat((BOX, boxf1), axis=0)
BOX = pd.concat((BOX, boxf2), axis=0)

BOX = pd.concat((BOX, boxfp1), axis=0)
BOX = pd.concat((BOX, boxfp2), axis=0)

BOX = pd.concat((BOX, boxfn1), axis=0)
BOX = pd.concat((BOX, boxfn2), axis=0)

BOX = pd.concat((BOX, boxu1), axis=0)
BOX = pd.concat((BOX, boxu2), axis=0)

BOX = pd.concat((BOX, boxb1), axis=0)
BOX = pd.concat((BOX, boxb2), axis=0)

BOX = pd.concat((BOX, boxc1), axis=0)
BOX = pd.concat((BOX, boxc2), axis=0)

colors = ['#0C7BDC', '#E66100', '#FFC20A', '#2C7300', '#8C564B', '#029E73', '#CC78BC']
sns.boxplot(data = BOX, x = 'node_type', y = 'C-index', hue='mode', palette=colors)

x1, x2 = -0.39, 0.25  # positions for groups A and B
y, h, col = 0.98, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = -0.26, 0.25  # positions for groups A and B
y, h, col = 0.94, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = -0.13, 0.25  # positions for groups A and B
y, h, col = 0.90, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.00, 0.25  # positions for groups A and B
y, h, col = 0.86, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.13, 0.25  # positions for groups A and B
y, h, col = 0.82, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

#x1, x2 = 0.7, 1.3  # positions for groups A and B
#y, h, col = 0.86, 0.005, 'k'  # y position, height, and color
#plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
#plt.text((x1+x2)*.5, y+h+0.001, "**", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.65, 1.23  # positions for groups A and B
y, h, col = 0.98, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.75, 1.23  # positions for groups A and B
y, h, col = 0.94, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 0.87, 1.23  # positions for groups A and B
y, h, col = 0.90, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 1.0, 1.23  # positions for groups A and B
y, h, col = 0.86, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

x1, x2 = 1.13, 1.23  # positions for groups A and B
y, h, col = 0.82, 0.005, 'k'  # y position, height, and color
plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
plt.text((x1+x2)*.5, y+h+0.001, "*", ha='center', va='bottom', color=col, fontsize=15)

plt.title('Isolated vs FedAvg vs FedSDS - BRCA')
plt.legend(title='Models',loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('Client where the model is evaluated')
plt.ylim(0.50,1.02)
plt.grid()
plt.savefig('C:/Users/Lenovo/Desktop/FedSDS_review/allboxplot_brca_review.png', bbox_inches='tight')

# %%
import numpy as np
from scipy import stats

for dd in [c11, c22, C1, C2,FP1,FP2,FN1,FN2,G11, G22, C11, C22]:
    print('mean: ', np.mean(dd), ' confidence interval: ', stats.t.interval(0.95, len(dd)-1, loc=np.mean(dd), scale=stats.sem(dd)))
# Out:
# mean:  0.6690997566909975  confidence interval:  (0.6564418125770427, 0.6817577008049523)
# mean:  0.6388518024032044  confidence interval:  (0.6128541711516708, 0.6648494336547379)
# mean:  0.6838199513381995  confidence interval:  (0.661460773873252, 0.706179128803147)
# mean:  0.6619492656875836  confidence interval:  (0.6427270162093284, 0.6811715151658388)
# mean:  0.6948905109489052  confidence interval:  (0.67596218829064, 0.7138188336071704)
# mean:  0.6829105473965287  confidence interval:  (0.6667570654816892, 0.6990640293113681)
# mean:  0.6841849148418492  confidence interval:  (0.6621871411616004, 0.706182688522098)
# mean:  0.6616822429906543  confidence interval:  (0.642590143176629, 0.6807743428046795)
# mean:  0.5425790754257908  confidence interval:  (0.5253878452383272, 0.5597703056132544)
# mean:  0.5389853137516688  confidence interval:  (0.5235847396759277, 0.5543858878274099)
# ...

# %%
# FACCIO IL TEST SOLO TRA I CORRISPONDENTI
from scipy.stats import mannwhitneyu, wilcoxon
from statsmodels.stats.multitest import multipletests

p_values = []
labels = []

alternative = 'greater'

def corrected_test(group1, group2, label):
    #stat, p = mannwhitneyu(round(group1,3), round(group2,3), alternative=alternative
    try:
        stat, p = wilcoxon(round(group1,3), round(group2,3), alternative=alternative)
        #stat, p = wilcoxon(group1, group2, alternative=alternative)
    except:
        p = 1.0
        label = "identity"
    p_values.append(p)
    labels.append(label)
    #print(f"{label}: statistic={stat}, raw p-value={p}")

#n1 = [c11,c21,c31,C1,G11,G21,G31,C11,C21,C31]
n1 = [c11, C1, G11, C11]
#n2 = [c12,c22,c32,C2,G12,G22,G32,C12,C22,C32]
n2 = [c22, C2, G22, C22]
#n3 = [c13,c23,c33,C3,G13,G23,G33,C13,C23,C33]
#n3 = [c33, C3, G33, C33]

medie1 = [np.mean(array) for array in n1]
medie2 = [np.mean(array) for array in n2]
#medie3 = [np.mean(array) for array in n3]

indice1= np.argmax(medie1)
indice2= np.argmax(medie2)
#indice3= np.argmax(medie3)


# Seleziona l'array con la media più alta
max1 = n1[indice1]
max2 = n2[indice2]
#max3 = n3[indice3]



# Run your tests (abbreviated for clarity; use all 30 like before)
corrected_test(max1, c11, "f11 vs i11")
#corrected_test(max1, c21, "f11 vs i21")
#corrected_test(max1, c31, "f11 vs i11")

#corrected_test(max2, c12, "f22 vs i12")
corrected_test(max2, c22, "f22 vs i22")
#corrected_test(max2, c32, "f2 vs i32")
#corrected_test(max3, c33, "f33 vs i33")
#corrected_test(max3, c13, "f33 vs i13")
#corrected_test(max3, c23, "f33 vs i23")


corrected_test(max1, C1, "f11 vs avg11")
corrected_test(max2, C2, "f22 vs avg22")
#corrected_test(max3, C3, "f33 vs avg33")

corrected_test(max1, FP1, "f11 vs fprox11")
corrected_test(max2, FP2, "f22 vs fprox22")
#corrected_test(max3, FP3, "f33 vs fprox33")

corrected_test(max1, FN1, "f11 vs fnova11")
corrected_test(max2, FN2, "f22 vs fnova22")
#corrected_test(max3, FN3, "f33 vs fnova33")


corrected_test(max1, G11, "f11 vs g11")
#corrected_test(max1, G21, "f11 vs g21")
#corrected_test(max1, G31, "f11 vs g11")

#corrected_test(max2, G12, "f11 vs g11")
corrected_test(max2, G22, "f22 vs g22")
#corrected_test(max2, G32, "f11 vs g11")
#corrected_test(max3, G33, "f33 vs g33")
#corrected_test(max3, G13, "f11 vs g11")
#corrected_test(max3, G23, "f11 vs g21")


corrected_test(max1, C11, "f11 vs f11")
#corrected_test(max1, C21, "f11 vs f21")
#corrected_test(max1, C31, "f11 vs f31")

#corrected_test(max2, C12, "f11 vs f12")
corrected_test(max2, C22, "f22 vs f22")
#corrected_test(max2, C32, "f11 vs f32")
#corrected_test(max3, C33, "f33 vs f33")
#corrected_test(max3, C13, "f11 vs f13")
#corrected_test(max3, C23, "f11 vs f23")


# Apply Holm-Bonferroni correction (FWER control)
reject, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='holm')

print(f"\nHolm-Bonferroni correction applied (FWER control).")
for i in range(len(p_values)):
    print(f"{labels[i]}: corrected p-value = {pvals_corrected[i]}, significant: {reject[i]}")
# Out:
# Holm-Bonferroni correction applied (FWER control).
# f11 vs i11: corrected p-value = 0.013671875, significant: True
# f22 vs i22: corrected p-value = 0.01171875, significant: True
# f11 vs avg11: corrected p-value = 0.013671875, significant: True
# f22 vs avg22: corrected p-value = 0.01171875, significant: True
# f11 vs fprox11: corrected p-value = 0.029296875, significant: True
# f22 vs fprox22: corrected p-value = 0.02734375, significant: True
# f11 vs fnova11: corrected p-value = 0.013671875, significant: True
# f22 vs fnova22: corrected p-value = 0.01171875, significant: True
# f11 vs g11: corrected p-value = 0.01171875, significant: True
# f22 vs g22: corrected p-value = 0.01171875, significant: True
# identity: corrected p-value = 1.0, significant: False
# identity: corrected p-value = 1.0, significant: False
# ...

# %%
#### negative transfer
i = [99,199,299,399,499,599,699,799,899,999]
fold = 'BRCA'
exp = 'brca'
c11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
c22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
G11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
G22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
i = [99,199,299,399,499,599,699,799,899]
FP1a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/BRCA_cindex_review_unbiased_0.1.csv', header=None)[1][:1000][i]
FP1b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/BRCA_cindex_review_unbiased_0.3.csv', header=None)[1][:1000][i]
FP1c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/BRCA_cindex_review_unbiased_0.5.csv', header=None)[1][:1000][i]
FP1d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/BRCA_cindex_review_unbiased_0.7.csv', header=None)[1][:1000][i]
FP1e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/BRCA/node1_brca_unbiased_ok.csv', header=None)[1][:1000][i]

FP2a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/BRCA_cindex_review_unbiased_0.1.csv', header=None)[1][:1000][i]
FP2b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/BRCA_cindex_review_unbiased_0.3.csv', header=None)[1][:1000][i]
FP2c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/BRCA_cindex_review_unbiased_0.5.csv', header=None)[1][:1000][i]
FP2d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/BRCA_cindex_review_unbiased_0.7.csv', header=None)[1][:1000][i]
FP2e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2//BRCA/node2_brca_unbiased_ok.csv', header=None)[1][:1000][i]

# %%
data = [FP1a,FP1b,FP1c,FP1d,FP1e]
l = 9

box1 = pd.DataFrame({'C-index':FP1a, 
                   'mode': ['Unbiased (10%)']*l,
                  'node_type':['Client 1']*l})
box2 = pd.DataFrame({'C-index':FP1b, 
                   'mode': ['Unbiased (30%)']*l,
                  'node_type':['Client 1']*l})
box3 = pd.DataFrame({'C-index':FP1c, 
                   'mode': ['Unbiased (50%)']*l,
                  'node_type':['Client 1']*l})
box4 = pd.DataFrame({'C-index':FP1d, 
                   'mode': ['Unbiased (70%)']*l,
                  'node_type':['Client 1']*l})
box5 = pd.DataFrame({'C-index':FP1e, 
                   'mode': ['Unbiased (100%)']*l,
                  'node_type':['Client 1']*l})
box6 = pd.DataFrame({'C-index':FP2a, 
                   'mode': ['Unbiased (10%)']*l,
                  'node_type':['Client 2']*l})
box7 = pd.DataFrame({'C-index':FP2b, 
                   'mode': ['Unbiased (30%)']*l,
                  'node_type':['Client 2']*l})
box8 = pd.DataFrame({'C-index':FP2c, 
                   'mode': ['Unbiased (50%)']*l,
                  'node_type':['Client 2']*l})
box9 = pd.DataFrame({'C-index':FP2d, 
                   'mode': ['Unbiased (70%)']*l,
                  'node_type':['Client 2']*l})
box10 = pd.DataFrame({'C-index':FP2e, 
                   'mode': ['Unbiased (100%)']*l,
                  'node_type':['Client 2']*l})

box11 = pd.DataFrame({'C-index':c11, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 1']*10})
box22 = pd.DataFrame({'C-index':c22, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 2']*10})

boxu1 = pd.DataFrame({'C-index':G11, 
                   'mode': ['Unbiased (100%)']*10,
                  'node_type':['Client 1']*10})
boxu2 = pd.DataFrame({'C-index':G22, 
                   'mode': ['Unbiased (100%)']*10,
                  'node_type':['Client 2']*10})

boxx = pd.concat((box1, box2),axis=0)
boxx = pd.concat((boxx, box3),axis=0)
boxx = pd.concat((boxx, box4),axis=0)

boxx = pd.concat((boxx, box6),axis=0)
boxx = pd.concat((boxx, box7),axis=0)
boxx = pd.concat((boxx, box8),axis=0)
boxx = pd.concat((boxx, box9),axis=0)

boxx = pd.concat((boxx, boxu1),axis=0)
boxx = pd.concat((boxx, boxu2),axis=0)
boxx = pd.concat((boxx, box11),axis=0)
boxx = pd.concat((boxx, box22),axis=0)
# =========================
# FIGURA
# =========================

fig, ax = plt.subplots(figsize=(8, 6))

# Boxplot
plt.title('Different amounts of unbiased synthetic data - BRCA', fontsize = 16)
sns.boxplot(data = boxx, x = 'node_type', y = 'C-index', hue='mode', palette=colors)
plt.legend(title='Models',loc='upper left', bbox_to_anchor=(1, 1), fontsize=9)
plt.xlabel('Client where the model is evaluated', fontsize = 14)
plt.ylabel('C-index', fontsize = 14)
plt.ylim(0.47,0.75)
plt.grid()
plt.savefig('C:/Users/Lenovo/Desktop/FedSDS_review/attribution_analysis_brca_review.png', bbox_inches='tight')
plt.show()

# %%
#### negative transfer
i = [99,199,299,399,499,599,699,799,899,999]
fold = 'LGG'
exp = 'lgg'
c11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
c22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_iso_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
G11 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/'+fold+'/node1_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
G22 = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/'+fold+'/node2_'+exp+'_unbiased_ok.csv', header=None)[1][:1000][i].reset_index(drop=True)
i = [99,199,299,399,499,599,699,799,899]
FP1a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/LGG_cindex_review_unbiased_0.1.csv', header=None)[1][:1000][i]
FP1b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/LGG_cindex_review_unbiased_0.3.csv', header=None)[1][:1000][i]
FP1c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/LGG_cindex_review_unbiased_0.5.csv', header=None)[1][:1000][i]
FP1d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/LGG_cindex_review_unbiased_0.7.csv', header=None)[1][:1000][i]
FP1e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/LGG_cindex_review_unbiased_0.9.csv', header=None)[1][:1000][i]
FP1f = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node1/LGG/node1_lgg_unbiased_ok.csv', header=None)[1][:1000][i]

FP2a = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/LGG_cindex_review_unbiased_0.1.csv', header=None)[1][:1000][i]
FP2b = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/LGG_cindex_review_unbiased_0.3.csv', header=None)[1][:1000][i]
FP2c = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/LGG_cindex_review_unbiased_0.5.csv', header=None)[1][:1000][i]
FP2d = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/LGG_cindex_review_unbiased_0.7.csv', header=None)[1][:1000][i]
FP2e = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/LGG_cindex_review_unbiased_0.9.csv', header=None)[1][:1000][i]
FP2f = pd.read_csv('C:/Users/Lenovo/Desktop/FedSDS_biased_flower/Node2/LGG/node2_lgg_unbiased_ok.csv', header=None)[1][:1000][i]

# %%
data = [FP1a,FP1b,FP1c,FP1d,FP1e]
l = 9

box1 = pd.DataFrame({'C-index':FP1a, 
                   'mode': ['Unbiased (10%)']*l,
                  'node_type':['Client 1']*l})
box2 = pd.DataFrame({'C-index':FP1b, 
                   'mode': ['Unbiased (30%)']*l,
                  'node_type':['Client 1']*l})
box3 = pd.DataFrame({'C-index':FP1c, 
                   'mode': ['Unbiased (50%)']*l,
                  'node_type':['Client 1']*l})
box4 = pd.DataFrame({'C-index':FP1d, 
                   'mode': ['Unbiased (70%)']*l,
                  'node_type':['Client 1']*l})
box5 = pd.DataFrame({'C-index':FP1e, 
                   'mode': ['Unbiased (90%)']*l,
                  'node_type':['Client 1']*l})
box5b = pd.DataFrame({'C-index':FP1f, 
                   'mode': ['Unbiased (100%)']*l,
                  'node_type':['Client 1']*l})
box6 = pd.DataFrame({'C-index':FP2a, 
                   'mode': ['Unbiased (10%)']*l,
                  'node_type':['Client 2']*l})
box7 = pd.DataFrame({'C-index':FP2b, 
                   'mode': ['Unbiased (30%)']*l,
                  'node_type':['Client 2']*l})
box8 = pd.DataFrame({'C-index':FP2c, 
                   'mode': ['Unbiased (50%)']*l,
                  'node_type':['Client 2']*l})
box9 = pd.DataFrame({'C-index':FP2d, 
                   'mode': ['Unbiased (70%)']*l,
                  'node_type':['Client 2']*l})
box10 = pd.DataFrame({'C-index':FP2e, 
                   'mode': ['Unbiased (90%)']*l,
                  'node_type':['Client 2']*l})
box10b = pd.DataFrame({'C-index':FP2f, 
                   'mode': ['Unbiased (100%)']*l,
                  'node_type':['Client 2']*l})
box11 = pd.DataFrame({'C-index':c11, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 1']*10})
box22 = pd.DataFrame({'C-index':c22, 
                   'mode': ['Isolated']*10,
                  'node_type':['Client 2']*10})
boxu1 = pd.DataFrame({'C-index':G11, 
                   'mode': ['Unbiased (100%)']*10,
                  'node_type':['Client 1']*10})
boxu2 = pd.DataFrame({'C-index':G22, 
                   'mode': ['Unbiased (100%)']*10,
                  'node_type':['Client 2']*10})

boxx = pd.concat((box1, box2),axis=0)
boxx = pd.concat((boxx, box3),axis=0)
boxx = pd.concat((boxx, box4),axis=0)
#boxx = pd.concat((boxx, box5),axis=0)
boxx = pd.concat((boxx, boxu1),axis=0)
boxx = pd.concat((boxx, box6),axis=0)
boxx = pd.concat((boxx, box7),axis=0)
boxx = pd.concat((boxx, box8),axis=0)
boxx = pd.concat((boxx, box9),axis=0)
#boxx = pd.concat((boxx, box10),axis=0)
boxx = pd.concat((boxx, boxu2),axis=0)
boxx = pd.concat((boxx, box11),axis=0)
boxx = pd.concat((boxx, box22),axis=0)
# =========================
# FIGURA
# =========================

fig, ax = plt.subplots(figsize=(8, 6))
colors = ['#0C7BDC', '#E66100', '#FFC20A', '#2C7300', '#8C564B', '#029E73', '#CC78BC']
# Boxplot
plt.title('Different amounts of unbiased synthetic data - LGG', fontsize = 16)
sns.boxplot(data = boxx, x = 'node_type', y = 'C-index', hue='mode', palette=colors)
plt.legend(title='Models',loc='upper left', bbox_to_anchor=(1, 1), fontsize = 9)
plt.xlabel('Client where the model is evaluated', fontsize = 14)
plt.ylabel('C-index', fontsize = 14)
plt.ylim(0.40,0.8)
plt.grid()
plt.savefig('C:/Users/Lenovo/Desktop/FedSDS_review/attribution_analysis_lgg_review.png', bbox_inches='tight')
plt.show()
